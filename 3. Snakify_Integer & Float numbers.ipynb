# %%
x = int(input())
print(x % 10)
# Out:
# 179
# 9

# %%
x = int(input())
print(x // 10 % 10)
# Out:
# 73
# 7

# %%
x = int(input())
a = x // 100
b = x // 10 % 10
c = x % 10
print(a + b + c)
# Out:
# 179
# 17

# %%
x = float(input())
print(x - int(x))
# Out:
# 17.9
# 0.8999999999999986

# %%
x = float(input())
print(int(x * 10) % 10)
# Out:
# 1.79
# 7

# %%
from math import ceil
n = int(input())
m = int(input())
print(ceil(m / n))
# Out:
# 700
# 750
# 2

# %%
n = int(input())
hours = n // 60
minutes = n % 60
print(hours, minutes)
# Out:
# 160
# 2 40

# %%
x = int(input())
y = int(input())
z = int(input())
cost = z * (100 * x + y)
print(cost // 100, cost % 100)
# Out:
# 3
# 5
# 7
# 21 35

# %%
h = int(input())
m = int(input())
s = int(input())
print(h * 30 + m * 30 / 60 + s * 30 / 3600)
# Out:
# 1
# 2
# 6
# 31.05

# %%
alpha = float(input())
print(alpha % 30 * 12)
# Out:
# 190
# 120.0
